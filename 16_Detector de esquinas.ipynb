# %%
# Detector de esquinas

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
pwd
# Out:
# 'C:\\Users\\alexp\\OneDrive\\DataScience\\Python Files\\Python Codes\\OpenCV'

# %%
cd Images_Class_3
# Out:
# C:\Users\alexp\OneDrive\DataScience\Python Files\Python Codes\OpenCV\Images_Class_3

# %%
ajedrez = cv2.imread('tablero-ajedrez.png')
ajedrez_gris = cv2.cvtColor(ajedrez, cv2.COLOR_BGR2GRAY)
plt.imshow(ajedrez_gris,cmap='gray')

# %%
esquinas = cv2.goodFeaturesToTrack(ajedrez_gris, 100, 0.01, 10)

# %%
esquinas = np.int0(esquinas)

# %%
#esquinas

# %%
for i in esquinas:
    x, y = i.ravel()
    cv2.circle(ajedrez, (x,y), 4, (255,0,0), 8)

# %%
plt.imshow(ajedrez)

# %%
ajedrez_real = cv2.imread('ajedrez-real.jpg')
ajedrez_real_gris = cv2.cvtColor(ajedrez_real,cv2.COLOR_BGR2GRAY)
plt.imshow(ajedrez_real_gris, cmap = 'gray')

# %%
esquinas = cv2.goodFeaturesToTrack(ajedrez_real_gris, 200, 0.01, 10)
esquinas = np.int0(esquinas)

# %%
#esquinas

# %%
for i in esquinas:
    x, y = i.ravel()
    cv2.circle(ajedrez_real, (x,y), 4, (255,0,0), 8)

# %%
plt.imshow(ajedrez_real)
