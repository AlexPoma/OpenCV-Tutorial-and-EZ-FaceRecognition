# %%
# cv2.threshold - Para convertir una imágen una imágene binaria

# %%
import matplotlib.pyplot as plt
import cv2

# %%
pwd
# Out:
# 'C:\\Users\\alexp\\OneDrive\\DataScience\\Python Files\\Python Codes\\OpenCV'

# %%
cd Images_Class_3
# Out:
# C:\Users\alexp\OneDrive\DataScience\Python Files\Python Codes\OpenCV\Images_Class_3

# %%
imagen = cv2.imread('perro.jpg')
plt.imshow(imagen)

# %%
imagen = cv2.imread('perro.jpg',0)
plt.imshow(imagen,cmap='gray')

# %%
mitad, imagen = cv2.threshold(imagen, 255/2, 255, cv2.THRESH_BINARY)
plt.imshow(imagen,cmap='gray')

# %%
mitad, imagen = cv2.threshold(imagen, 255/2, 255, cv2.THRESH_BINARY_INV)
plt.imshow(imagen,cmap='gray')
